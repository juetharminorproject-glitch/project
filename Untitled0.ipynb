# %%
import zipfile

zip_path = "/content/human+activity+recognition+using+smartphones.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/human_activity_project")

print("Project extracted successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1418/1158999154.py in <cell line: 0>()
#       3 zip_path = "/content/human+activity+recognition+using+smartphones.zip"
#       4
# ----> 5 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       6     zip_ref.extractall("/content/human_activity_project")
#       7
#
# /usr/lib/python3.13/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1387             while True:
#    1388                 try:
# -> 1389                     self.fp = io.open(file, filemode)
#    1390                 except OSError:
#    1391                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/human+activity+recognition+using+smartphones.zip'

# %%
import zipfile
import os

zip_path = "/content/human+activity+recognition+using+smartphones.zip"

extract_path = "/content/human_activity_project"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Project extracted successfully!")

# %%
import os

for root, folders, files in os.walk("/content/human_activity_project"):
    for file in files:
        print(os.path.join(root, file))

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Classroom',
#  'Screenshot_20240914-205717_Gallery.jpg',
#  'Screenshot_20241008-190311_Drive.jpg',
#  '3_MadLab-3.mp4',
#  'Blank Quiz (1).gform',
#  'Screenshot_20250207-095857_Gallery.jpg',
#  'Blank Quiz.gform',
#  'UI UX LAB',
#  'PREETI SOLANKI - Internship Application Generator.gdoc',
#  '1-3104a4c6-4dfa-4b67-8b8c-c62ccbc975f6.pdf',
#  'Screenshot_20251119-132156_Drive.jpg',
#  'Colab Notebooks',
#  'Demo for practice.pdf',
#  'week 1',
#  'week 2',
#  '1.A.png',
#  'Copy of 3_MadLab-3.mp4',
#  'ML',
#  'Lecture 1.pptx',
#  'Lab_6.ipynb',
#  'Lab5_APS.ipynb',
#  '2.Agents in AI_without_first_slide (1).pdf',
#  '1.AI Intro (1).pdf',
#  'Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf',
#  'Demo practice pandas basics.docx',
#  '1000142826.jpg.adding',
#  '1000142824.jpg',
#  '1000142825.jpg',
#  '1000142821.jpg',
#  '1000142817.jpg',
#  '1000142811.jpg',
#  '1000142820.jpg',
#  '1000142828.jpg',
#  '1000144610.jpg',
# ...

# %%
import os

project_folder = "/content/drive/MyDrive/Human Activity Recognition Project"

os.makedirs(project_folder, exist_ok=True)

print("Project folder created successfully!")
# Out:
# Project folder created successfully!

# %%
import shutil

shutil.copy(
    "/content/human+activity+recognition+using+smartphones.zip",
    "/content/drive/MyDrive/Human Activity Recognition Project/"
)

print("ZIP file saved to Google Drive successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1418/1499866125.py in <cell line: 0>()
#       1 import shutil
#       2
# ----> 3 shutil.copy(
#       4     "/content/human+activity+recognition+using+smartphones.zip",
#       5     "/content/drive/MyDrive/Human Activity Recognition Project/"
#
# /usr/lib/python3.13/shutil.py in copy(src, dst, follow_symlinks)
#     426     if os.path.isdir(dst):
#     427         dst = os.path.join(dst, os.path.basename(src))
# --> 428     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     429     copymode(src, dst, follow_symlinks=follow_symlinks)
#     430     return dst
#
# /usr/lib/python3.13/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
# ...

# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
import zipfile
import os

project_path = "/content/drive/MyDrive/UCI HAR ML Project"

zip_path = os.path.join(
    project_path,
    "human+activity+recognition+using+smartphones.zip"
)

# Extract the outer ZIP
with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall('/content/outer')

# Extract the inner ZIP
inner_zip = '/content/outer/UCI HAR Dataset.zip'

with zipfile.ZipFile(inner_zip, 'r') as z:
    z.extractall('/content/har')

print("Dataset extracted successfully!")

# %%
import os

project_path = "/content/drive/MyDrive/UCI HAR ML Project"

print("Files in project folder:")
print(os.listdir(project_path))

# %%
import os

project_path = "/content/drive/MyDrive/UCI HAR ML Project"

os.makedirs(project_path, exist_ok=True)

print("Folder created successfully!")

# %%
print(os.listdir("/content/drive/MyDrive"))

# %%
import os

print(os.listdir("/content"))

# %%
import shutil

shutil.copy(
    "/content/human+activity+recognition+using+smartphones.zip",
    "/content/drive/MyDrive/UCI HAR ML Project/"
)

print("ZIP copied to Google Drive successfully!")

# %%
import os

print(os.listdir("/content/drive/MyDrive/UCI HAR ML Project"))

# %%
import zipfile
import os

project_path = "/content/drive/MyDrive/UCI HAR ML Project"

zip_path = os.path.join(
    project_path,
    "human+activity+recognition+using+smartphones.zip"
)

outer_path = "/content/outer"
os.makedirs(outer_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(outer_path)

print("Outer ZIP extracted successfully!")
print(os.listdir(outer_path))

# %%
import zipfile
import os

inner_zip = "/content/outer/UCI HAR Dataset.zip"
har_path = "/content/har"

os.makedirs(har_path, exist_ok=True)

with zipfile.ZipFile(inner_zip, 'r') as z:
    z.extractall(har_path)

print("Dataset extracted successfully!")

# %%
import os

for root, folders, files in os.walk("/content/har"):
    for file in files:
        print(os.path.join(root, file))

# %%
y_test, y_pred_lr))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Create Logistic Regression model
logistic_model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

# Train the model
logistic_model.fit(X_train, y_train.values.ravel())

# Make predictions
y_pred_lr = logistic_model.predict(X_test)

# Calculate accuracy
accuracy_lr = accuracy_score(y_test, y_pred_lr)

print("Logistic Regression Accuracy:", accuracy_lr)

print("\nClassification Report:")
print(classification_report(
